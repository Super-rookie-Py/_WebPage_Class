# %% [markdown]
# <a href="https://colab.research.google.com/github/Super-rookie-Py/_WebProgramming_Class/blob/master/%EB%B0%95%EA%B1%B4%EC%9A%B0__%EB%84%A4%EC%9D%B4%EB%B2%84_%EB%89%B4%EC%8A%A4_%EA%B8%B0%EC%82%AC_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BeautyfulSoup 네이버 뉴스 기사 스크래핑
#
# - keonwoo Park 2020/09/14

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd

def get_news(query, page_num):

  news_df = pd.DataFrame(columns=("Title", "Link", "Press", "Datetime", "Article"))
  idx = 0

  url_query = quote(query)
  url = "https://search.naver.com/search.naver?where=news&sm=nws_hty&query=" + url_query
  for _ in range(0, page_num):

    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')
    links = soup.find_all('dd', {'class': 'txt_inline'})

    for link in links:
      press = link.find('span', {'class': '_sp_each_source'}).get_text()
      news_url = link.find('a').get('href')

      if (news_url == "#"):
        continue
      else:
        try: 
          news_link = urllib.request.urlopen(news_url).read()
          news_html = BeautifulSoup(news_link, "html.parser")

          title = news_html.find('h3', {'id': 'articleTitle'}).get_text()
          datetime = news_html.find('span', {'class': 't11'}).get_text()
          article = news_html.find('div', {'id': 'articleBodyContents'}).get_text()
          article = article.replace("// flash 오류를 우회하기 위한 함수 추가", "")
          article = article.replace("function _flash_removeCallback() {}", "")
          article = article.replace("\n", "")
          article = article.replace("\t", "")
        

          news_df.loc[idx] = [title, news_url, press,datetime, article]
          idx +=1
          print("#", end="")
        except:
          continue
    try:  
      next = soup.find('a', {'class':'next'}).get('href')
      url = "https://search.naver.com/search.naver" + next
    except:
      break

  return news_df

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행

# %%
query = input("검색 질의: ")
news_df = get_news(query, 10)
print("Done")
# Out:
# 검색 질의: 인공지능
# ############################################Done

# %%
news_df
# Out:
#                                          Title  ...                                            Article
# 0                        인공지능, 의사 도와 의료현장 전면으로  ...  일부 영역 전문의보다 더 정확하게 진단의료AI 전문기업 뷰노 연구진들이 인공지능 솔...
# 1           LG, 인공지능 기반 화학소재 개발 나선다…AI 컨소시엄 결성  ...    서울시 강서구 마곡산업단지에 위치한 LG사이언스파크 전경. [사진 LG]    ...
# 2                         [미디어 세상]인공지능 편집자의 미덕  ...  [경향신문] 잠시 당신이 새 언론사 편집국장이 됐다고 생각해 보자. 내용적으로 저열...
# 3                인공지능 활용해 초등 1·2학년 수학 학습격차 줄인다  ...  교육부, 인공지능 활용 시스템 전국 초등학교에 보급내년 2학기에 고교에 '인공지능 ...
# 4           언택트 시대, 인공지능 면접 체험하고 K-물류 구직해법 찾아요  ...  15일부터 온라인 '물류산업 청년 채용박람회'물류산업 청년 채용박람회 홍보 포스터....
# 5            가톨릭대, 인공지능학과·의생명과학과 신설…교과 반영방법 변경  ...  가톨릭대학교 전경 (가톨릭대 제공) © 뉴스1(서울=뉴스1) 권형진 기자 = 가톨릭...
# 6           뷰노, 대한아동병원협회와 ‘인공지능 의료솔루션 상용화’ MOU  ...  김현준 뷰노 대표(왼쪽)와 최용재 대한아동병원협회 부회장이 10일 인공지능 의료솔루...
# 7        가천대, 인공지능전공 150명 모집·취업 계약학과 신설 [수시특집]  ...     가천대학교 2021학년도 모집인원은 총 4305명으로 수시에서 약 70%인 3...
# 8         한양대, 인공지능·심리학 접목… ‘심리뇌과학과’ 신설 [수시특집]  ...     한양대학교 2021학년도 입시의 가장 큰 특징은 심리뇌과학과 신설이다. 인공지...
# 9            광주시·애자일소다, ‘인공지능 비즈니스 기반 조성’ 업무협약  ...  AI 분석 컨설팅·교육 등 위한 광주법인 및 지역사무소 설립최대우 대표 "AI 경험...
# 10    인공지능 탑재한 물걸레 전용 로봇청소기 ‘LG 코드제로 M9 ThinQ’  ...  /사진=LG전자2020년 기준 1340조원에 달하는 가전 시장의 최신 트랜드는 ‘워...
# 11              KT, 앨리웨이 광교에 인공지능 주차·로봇 서비스 제공  ...  KT-네오밸류프라퍼티, 부동산 개발 및 운영 사업협력 MOU(서울=연합뉴스) 10일...
# 12               이재웅 “인공지능(AI) 뉴스편집, 과연 중립적일까”  ...  이재웅 전 쏘카 대표 /사진=뉴시스 [파이낸셜뉴스] 포털사이트 ‘다음(DAUM)’을...
# 13     인공지능 기술 스타트업 ‘아드리엘’, 채용 한파 뚫고 하반기 채용 실시  ...  3분기 큰 폭의 성장 기록하며 개발 직군, 마케터 직군 충원 진행[헤럴드경제] 코로...
# 14                     세종대, '인공지능 채용' 대비 특강 열어  ...  세종대 대학일자리사업단 관계자가 비대면 'AI채용 이해 및 AI솔루션 활용' 특강을...
# 15                   네이버·연세대, 인공지능 우수 인재 공동 육성  ...  [네이버 제공. 재판매 및 DB 금지]    (서울=연합뉴스) 홍지인 기자 = 네이...
# 16       [지디의 네웹소설] 인공지능-내과 의사 짜릿한 공생 ‘A.I 닥터’  ...  ‘중증외상센터: 골든 아워’ 한산이가 작가 집필(지디넷코리아=백봉삼  기자)최첨단 ...
# 17            인공지능 요리 LG디오스 광파오븐, 올해 들어 30% 성장  ...  (서울=연합뉴스) 김영신 기자 = LG전자는 인공지능 요리 기능을 갖춘 'LG 디오...
# 18                  KAIST, 중기부와 인공지능 제조 플랫폼 구축  ...  중소기업이 구축한 스마트공장에 인공지능(AI)을 활용할 수 있도록 돕는 플랫폼이 구...
# 19          코로나19 이후 인공지능 역할은…SKT ai.x 콘퍼런스 개최  ...  (서울=연합뉴스) 조성흠 기자 = SK텔레콤은 이달 10일  AI를 활용해 현재와 ...
# 20               [유레카] 윤영찬과 인공지능 편집의 중립성 / 구본권  ...  지난 8일 윤영찬 더불어민주당 의원이 포털 사이트의 뉴스 편집에 대해 문제를 제기한...
# 38                  인공지능·심리학 접목 ‘심리뇌과학과’ 신설 주목  ...  이재진 입학처장한양대학교는 2021학년도 수시모집에서 총 1996명을 선발한다. 인...
# 39  오렌지라이프, 인공지능 적용한 &apos보험사기 사전 예측모델&apos 구축  ...  계약체결 시점부터 사기 여부 판단(지디넷코리아=차재서  기자)오렌지라이프가 빅데이터...
# 40            의료 AI 연구개발 활성화 ‘의료 인공지능 경진대회’ 개최  ...  서울대병원 주최… MAIC 홈페이지로 온라인 참가 방식‘수술 중 저혈압 예측’ 모델...
# 41                장석영 제2차관, 포항공과대학교 인공지능대학원 방문  ...      (서울=연합뉴스) 장석영 과학기술정보통신부 제2차관이 11일 오후 경상북도 ...
# 42                  SW학부 인공지능전공 모집인원 150명으로 확대  ...  가천대학교[경향신문] 이재희 입학처장가천대학교 2021학년도 모집인원은 총 4305...
# 43                카카오엔터프라이즈, 인공지능(AI) 포닥 지원 확대  ...  - 딥러닝 등 12개 분야 AI 박사후연구원 지원 프로그램 마련   [디지털데일리 ...
#
# [44 rows x 5 columns]

# %%
news_df['Article']
# Out:
# 0     일부 영역 전문의보다 더 정확하게 진단의료AI 전문기업 뷰노 연구진들이 인공지능 솔...
# 1       서울시 강서구 마곡산업단지에 위치한 LG사이언스파크 전경. [사진 LG]    ...
# 2     [경향신문] 잠시 당신이 새 언론사 편집국장이 됐다고 생각해 보자. 내용적으로 저열...
# 3     교육부, 인공지능 활용 시스템 전국 초등학교에 보급내년 2학기에 고교에 '인공지능 ...
# 4     15일부터 온라인 '물류산업 청년 채용박람회'물류산업 청년 채용박람회 홍보 포스터....
# 5     가톨릭대학교 전경 (가톨릭대 제공) © 뉴스1(서울=뉴스1) 권형진 기자 = 가톨릭...
# 6     김현준 뷰노 대표(왼쪽)와 최용재 대한아동병원협회 부회장이 10일 인공지능 의료솔루...
# 7        가천대학교 2021학년도 모집인원은 총 4305명으로 수시에서 약 70%인 3...
# 8        한양대학교 2021학년도 입시의 가장 큰 특징은 심리뇌과학과 신설이다. 인공지...
# 9     AI 분석 컨설팅·교육 등 위한 광주법인 및 지역사무소 설립최대우 대표 "AI 경험...
# 10    /사진=LG전자2020년 기준 1340조원에 달하는 가전 시장의 최신 트랜드는 ‘워...
# 11    KT-네오밸류프라퍼티, 부동산 개발 및 운영 사업협력 MOU(서울=연합뉴스) 10일...
# 12    이재웅 전 쏘카 대표 /사진=뉴시스 [파이낸셜뉴스] 포털사이트 ‘다음(DAUM)’을...
# 13    3분기 큰 폭의 성장 기록하며 개발 직군, 마케터 직군 충원 진행[헤럴드경제] 코로...
# 14    세종대 대학일자리사업단 관계자가 비대면 'AI채용 이해 및 AI솔루션 활용' 특강을...
# 15    [네이버 제공. 재판매 및 DB 금지]    (서울=연합뉴스) 홍지인 기자 = 네이...
# 16    ‘중증외상센터: 골든 아워’ 한산이가 작가 집필(지디넷코리아=백봉삼  기자)최첨단 ...
# 17    (서울=연합뉴스) 김영신 기자 = LG전자는 인공지능 요리 기능을 갖춘 'LG 디오...
# 18    중소기업이 구축한 스마트공장에 인공지능(AI)을 활용할 수 있도록 돕는 플랫폼이 구...
# 19    (서울=연합뉴스) 조성흠 기자 = SK텔레콤은 이달 10일  AI를 활용해 현재와 ...
# 20    지난 8일 윤영찬 더불어민주당 의원이 포털 사이트의 뉴스 편집에 대해 문제를 제기한...
# 21    경상대 가좌캠퍼스 전경[연합뉴스 자료사진](진주=연합뉴스) 지성호 기자 = 국립 경...
# 22    카카오 "인위적 개입 불가" 해명에도 정치권 논란... 학계에선 알고리즘 공개 요구...
# 23    중소벤처기업부, 8개 과제 제시중소벤처기업부[중소벤처기업부 제공]    (서울=연합...
# 24    지난 6월 IMDRF 실무그룹 의장국 선정의료·산업계 등 14인 전문가 협의체 구성...
# 25    한국과학기술원 전경[연합뉴스 자료사진](대전=연합뉴스) 박주영 기자 = KAIST(...
# 26    경희대병원 내분비내과 이상열 교수가 에릭 토플이 출판한 딥메디슨을 번역·출간했다./...
# 27    [서울=뉴시스]장석영 과학기술정보통신부 제2차관이 11일 경북 포항시 남구 포항우체...
# 28    [2021 대학 가는 길] 가천대학교이재희 입학처장가천대학교는 2021학년도 모집인...
# 29    정부가 차세대 비메모리 반도체 산업 육성을 위해 2029년까지 총 1조96억원을 투...
# 30    [머니투데이 김수현 기자] [포스트 코로나 시대 인간과 함께하는 AI 모색…올해 3...
# 31    [한국경제TV 김선엽 기자]의료 인공지능 기업 제이엘케이가 광운대와 손잡고 인공지능...
# 32    주호영 기사 메인에 뜨자 "카카오 들어오라고 하라"윤영찬 "이낙연 대표 연설 메인에...
# 33    사진설명:인공지능검사기술을 적용한 마스크 생산공정국립한경대학교 한국미래융합기술연구원...
# 34    서울과학기술대학교[경향신문] 신현상 입학관리본부장서울과학기술대학교는 서울 소재 국립...
# 35    [2021 대학 가는 길] 가톨릭대학교김준석 입학처장가톨릭대학교는 2021학년도 수...
# 36    지금 대덕에선…대전 비엔날레 2020 ‘AI:햇살은…’ 12월까지 시립미술관-KAI...
# 37    (KTH 제공)© 뉴스1(서울=뉴스1) 최동현 기자 = KTH는 인공지능(AI) C...
# 38    이재진 입학처장한양대학교는 2021학년도 수시모집에서 총 1996명을 선발한다. 인...
# 39    계약체결 시점부터 사기 여부 판단(지디넷코리아=차재서  기자)오렌지라이프가 빅데이터...
# 40    서울대병원 주최… MAIC 홈페이지로 온라인 참가 방식‘수술 중 저혈압 예측’ 모델...
# 41        (서울=연합뉴스) 장석영 과학기술정보통신부 제2차관이 11일 오후 경상북도 ...
# 42    가천대학교[경향신문] 이재희 입학처장가천대학교 2021학년도 모집인원은 총 4305...
# 43    - 딥러닝 등 12개 분야 AI 박사후연구원 지원 프로그램 마련   [디지털데일리 ...
# Name: Article, dtype: object
