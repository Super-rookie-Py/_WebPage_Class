# %% [markdown]
# <a href="https://colab.research.google.com/github/Super-rookie-Py/_WebProgramming_Class/blob/master/%EB%B0%95%EA%B1%B4%EC%9A%B0__%EC%9B%B9_%EC%82%AC%EC%9D%B4%ED%8A%B8_%EC%88%9C%EC%9C%84_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BeautyfulSoup 웹 사이트 순위 스크래핑
#
# * Alexa: https://www.alexa.com/topsites
#
# - keonwoo Park 2020/09/14

# %% [markdown]
# # 글로벌 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns = ("Rank", 'Site', "Daily Time on Site", 
                                  "Daily Pageviews per Visitor", "% of Traffic From Search",
                                  "Total Sites Linking In"))
sites = soup.find_all('div', {'class': 'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class':'td'}).get_text()
  web_site = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, web_site, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,311,039
# 2     2          Youtube.com  ...                   15.10%              1,000,374
# 3     3            Tmall.com  ...                    0.90%                  4,937
# 4     4            Baidu.com  ...                    5.10%                103,129
# 5     5               Qq.com  ...                    2.90%                263,438
# 6     6         Facebook.com  ...                    8.30%              2,265,001
# 7     7             Sohu.com  ...                    1.60%                 27,873
# 8     8           Taobao.com  ...                    3.30%                 25,272
# 9     9               360.cn  ...                    0.40%                 15,549
# 10   10               Jd.com  ...                    1.40%                  8,769
# ...

# %% [markdown]
# ## 미국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/US"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns = ("Rank", 'Site', "Daily Time on Site", 
                                  "Daily Pageviews per Visitor", "% of Traffic From Search",
                                  "Total Sites Linking In"))
sites = soup.find_all('div', {'class': 'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class':'td'}).get_text()
  web_site = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, web_site, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,311,039
# 2     2          Youtube.com  ...                   15.10%              1,000,374
# 3     3           Amazon.com  ...                   19.70%                359,590
# 4     4            Yahoo.com  ...                    7.80%                317,662
# 5     5         Facebook.com  ...                    8.30%              2,265,001
# 6     6              Zoom.us  ...                   15.00%                  2,921
# 7     7           Reddit.com  ...                   29.20%                170,026
# 8     8        Wikipedia.org  ...                   73.70%                760,453
# 9     9        Myshopify.com  ...                    3.20%                    120
# 10   10             Ebay.com  ...                   16.10%                 74,086
# ...

# %% [markdown]
# # 한국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/KR"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns = ("Rank", 'Site', "Daily Time on Site", 
                                  "Daily Pageviews per Visitor", "% of Traffic From Search",
                                  "Total Sites Linking In"))
sites = soup.find_all('div', {'class': 'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class':'td'}).get_text()
  web_site = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, web_site, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search Total Sites Linking In
# 1     1         Google.com  ...                    0.40%              1,311,039
# 2     2          Naver.com  ...                   10.10%                 38,898
# 3     3        Youtube.com  ...                   15.10%              1,000,374
# 4     4           Daum.net  ...                    4.70%                 15,053
# 5     5        Tistory.com  ...                   24.20%                  9,953
# 6     6          Tmall.com  ...                    0.90%                  4,937
# 7     7          Kakao.com  ...                    8.40%                 11,146
# 8     8       Google.co.kr  ...                    9.90%                  5,086
# 9     9         Amazon.com  ...                   19.70%                359,590
# 10   10       Facebook.com  ...                    8.30%              2,265,001
# 11   11          Namu.wiki  ...                   20.80%                    111
# ...
