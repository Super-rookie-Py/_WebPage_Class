# %% [markdown]
# <a href="https://colab.research.google.com/github/Super-rookie-Py/_WebProgramming_Class/blob/master/%EB%B0%95%EA%B1%B4%EC%9A%B0__%EB%84%A4%EC%9D%B4%EB%B2%84_%EA%B2%80%EC%83%89_API_%EC%84%9C%EB%B9%84%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# - keonwoo Park 2020/09/11

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns = ('Title','Link','Description'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        web_df.loc[idx] = [title,link,description]
        idx += 1
  else:
      print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의:컴퓨터
#                           Title  ...                                        Description
# 0                    컴퓨터 - 나무위키  ...  컴퓨터에 대한 내용은 PC 문서를 참조하십시오. 관련 문서: 전자기기 관련 정보, ...
# 1                  슈퍼컴퓨터 - 나무위키  ...  가장 빠른 슈퍼컴퓨터 연혁 4.2. 대한민국의 슈퍼컴퓨터 도입 4.2.1. 기상청 ...
# 2                          주연테크  ...  주연테크 회사소개 및 컴퓨터,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 ...
# 3                          TG삼보  ...                  컴퓨터, 모니터, 노트북 제조판매 등 제품소개, AS 안내.
# 4                        한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# ..                          ...  ...                                                ...
# 195                  컴퓨터학부 특강안내  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 132 등록일 : 2019-11-21...
# 196           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 122 등록일 : 2019...
# 197           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 495 등록일 : 2019...
# 198  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 97 등록일 : 2019-11-21 ...
# 199  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 95 등록일 : 2019-...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns = ('Title','Link','Description'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        kin_df.loc[idx] = [title,link,description]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의:컴퓨터
#                 Title  ...                                        Description
# 0       컴퓨터학원 유명한곳이요!  ...  제가 컴퓨터학원 다니려고 알아보고 있는데욥~ 이왕이면 가장 유명한 컴퓨터학원에 다니...
# 1      컴퓨터 사용도중 블루스크린  ...  ... 컴퓨터로 롤을 하다가 게임화면이 멈추더니 튕기고... 그러다가 컴퓨터가 꺼지...
# 2           컴퓨터스피커 추천  ...  ... 있긴한데 컴퓨터스피커 하나 더 있으면 괜찮을거같은데요 화이트톤의 컴퓨터인데 ...
# 3       기초컴퓨터학원 배울곳은?  ...  ... 약해서 컴퓨터학원 알아보고 다녀보려고 하는데요. 관련 자격증도 여러개 취득해...
# 4         학점은행제 컴퓨터공학  ...  ... 하던데 컴퓨터공학 있나요? 학점은행제 컴퓨터공학은 전공이 있나요 없나요? 학...
# ..                ...  ...                                                ...
# 995            컴퓨터 멈춤  ...  제가 컴퓨터가 안켜져서 수리를 맡긴지 3일짼데요 게임을 할때마다 컴퓨터가 멈춰요 키...
# 996  컴퓨터 조립 A/S 직업 질문  ...  컴퓨터조립 A/S 에 대한 질문을 할꺠요 간단한 답변 부탁드림니다 컴퓨터 조립 직업...
# 997       컴퓨터 질문드립니다.  ...  저희집 컴퓨터가 삼성컴퓨터 DM300S3A-A31R 인데요 한 2~3년썻구요 이컴퓨...
# 998         컴퓨터공학과 질문  ...  안녕하세요 지금고2 이과생인데 컴퓨터공학과를 가고싶습니다. 현재... 1.컴퓨터공학...
# 999     조립형컴퓨터 완제품으로!  ...  제가 조립형컴퓨터 급하게 구매할일이 생겼는데 저사양보다는 80만원대 어느정도 사양좋...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns = ('Title','Original Link','Link','Description','PubDate'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/news?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        originallink = items[item_index]['originallink']
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        pub_date = items[item_index]['pubDate']
        news_df.loc[idx] = [title,originallink,link, description, pub_date]
        idx += 1
  else:
      print("Error Code:" + rescode)

news_df
# Out:
# 검색 질의:컴퓨터
#                                       Title  ...                          PubDate
# 0             코로나19 소비회복도 양극화…승용차·컴퓨터 소비 껑충  ...  Thu, 10 Sep 2020 12:03:00 +0900
# 1                급발진 차량 약국 돌진...유리벽·컴퓨터도 박살  ...  Fri, 11 Sep 2020 12:24:00 +0900
# 2                오늘도 옷을 차려입고, 컴퓨터 방으로 출근합니다  ...  Thu, 10 Sep 2020 14:40:00 +0900
# 3                컴퓨터 펜으로 그린 '찰나의 자연' [이 전시]  ...  Thu, 10 Sep 2020 18:29:00 +0900
# 4              우리집 컴퓨터 보안 점검 정부가 원격으로 해 준대~  ...  Thu, 10 Sep 2020 17:24:00 +0900
# ..                                      ...  ...                              ...
# 995       삼성 컴퓨터, 미국서 신뢰도 4위… 지난해보다 3단계 떨어져  ...  Sun, 21 Jun 2020 23:02:00 +0900
# 996  경북교육청, AI 교육기반 마련 박차...미래 컴퓨터교육실 시범 구축  ...  Thu, 09 Jul 2020 16:06:00 +0900
# 997              비트컴퓨터, 의료정보솔루션업체 '자인컴' 인수   ...  Mon, 29 Jun 2020 12:50:00 +0900
# 998            광주 남구, 온라인 수업용 행정 컴퓨터 50대 지원  ...  Mon, 13 Apr 2020 14:23:00 +0900
# 999         일본 슈퍼컴퓨터, 美·中 제치고 9년만에 세계 1위 탈환  ...  Tue, 23 Jun 2020 14:50:00 +0900
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

blog_df = pd.DataFrame(columns = ('Title','Link','Description','Bloggername','Bloggerlink','Post_date'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        bloggername = items[item_index]['bloggername']
        bloggerlink = items[item_index]['bloggerlink']
        post_date = items[item_index]['postdate']
        blog_df.loc[idx] = [title,link,description, bloggername, bloggerlink,post_date]
        idx += 1
  else:
      print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의:컴퓨터
#                                            Title  ... Post_date
# 0                              컴퓨터학원 눈 여겨서 볼 정보!  ...  20200906
# 1                              와이프 컴퓨터 조립 -부품구입-  ...  20200908
# 2                             강남컴퓨터학원 꿈을 위한 한걸음!  ...  20200825
# 3                           국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 4                             컴퓨터 부팅 안될때 바로 고쳤어요  ...  20200910
# ..                                           ...  ...       ...
# 995                집에서 즐기는 넥슨컴퓨터박물관, 360 버추얼 뮤지엄  ...  20200417
# 996                            70만원대 80만원대 조립컴퓨터  ...  20200519
# 997                     게임 시뮬레이션 용도  고사양 조립컴퓨터출고  ...  20200625
# 998                  출판물 편집 인디자인 컴퓨터 애플맥 신형으로 교체  ...  20200226
# 999  한성컴퓨터 신규 데스크탑 브랜드케이스, BossMonster ULTRA...   ...  20200720
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

book_df = pd.DataFrame(columns = ('Title','Link','Image','Author','Price','Discount','Publisher','ISBN',"Description", "Publication Date"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/book?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        author = items[item_index]['author']
        price = items[item_index]['price']
        discount = items[item_index]['discount']
        publisher = items[item_index]['publisher']
        isbn = items[item_index]['isbn']
        description = re.sub(remove_tag,'',items[item_index]['description'])
        pubdate = items[item_index]['pubdate']
        book_df.loc[idx] = [title,link,image, author, price,discount,publisher,isbn,description,pubdate]
        idx += 1
  else:
      print("Error Code:" + rescode)

book_df
# Out:
# 검색 질의:컴퓨터
#                                                  Title  ... Publication Date
# 0    시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 1                              시나공 컴퓨터활용능력 2급실기 (2020)  ...         20191008
# 2                              시나공 컴퓨터활용능력1급 실기 (2020)  ...         20191010
# 3    시나공 총정리 컴퓨터활용능력 2급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 4    시나공 컴퓨터활용능력 1급 필기 (필수암기집+동영상강의+암기프로그램+기출CBT,2020)  ...         20191028
# ..                                                 ...  ...              ...
# 995              이기적 in 컴퓨터그래픽스 운용기능사 필기 기본서 세트 (2016)  ...         20151030
# 996                                              뉴로컴퓨터  ...         20000331
# 997                       시나공 총정리 컴퓨터활용능력 2급 필기 (2014)  ...         20131125
# 998                                WIN-Q 컴퓨터응용선반 밀링기능사  ...         20160810
# 999                  이기적in 컴퓨터그래픽스 운용기능사 실기 기본서 (2013)  ...         20121123
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

movie_df = pd.DataFrame(columns = ('Title','Link','Image','Subtitle','Publication Date','Director','Actor','User Rating'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']

        subtitle = items[item_index]['subtitle']
        pub_date = items[item_index]['pubDate']
        director = items[item_index]['director']
        actor = items[item_index]['actor']
        user_rating = items[item_index]['userRating']
        movie_df.loc[idx] = [title,link,image, subtitle, pub_date,director,actor,user_rating]
        idx += 1
  else:
      print("Error Code:" + rescode)

movie_df
# Out:
# 검색 질의:아이언맨
#                    Title  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
client_id = "SuUZls_ZKGMMmn4jFSkf"
client_secret = "L4kR2gA_gC"

query = urllib.parse.quote(input("검색 질의:"))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns = ('Title','Link','Image','Low Price',"High Price",'Mall Name','Product Id','Product Type','Maker','Brand'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
  + "&display="+ str(display) \
  + "&start=" + str(start_index)\
  + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']

        low_price = items[item_index]['lprice']
        high_price = items[item_index]['hprice']
        mall_name = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        shop_df.loc[idx] = [title,link,image, low_price, high_price,mall_name,product_id,product_type, maker, brand]
        idx += 1
  else:
      print("Error Code:" + rescode)

shop_df
# Out:
# 검색 질의:컴퓨터
#                                                  Title  ...   Brand
# 0              프리미엄 게이밍 조립컴퓨터 배틀그라운드 오버워치 배그 본체 사무용 견적  ...    마루PC
# 1      10세대PC i5-10400 i7-10700게이밍 조립컴퓨터 배틀그라운드 사무용노마드  ...  대한컴퓨터샵
# 2                    아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...     아싸컴
# 3                                삼성전자 삼성 DM500T9A-A58A  ...      삼성
# 4                                    LG전자 24V570-LRP1K  ...    LG전자
# ..                                                 ...  ...     ...
# 995                      셀텍 Thin H310 i3-9100T 90W SSD  ...      셀텍
# 996                                    주연테크 TINY-94F5T  ...    주연테크
# 997                     오존컴퍼니 VIPER Alu H310 G5400 SSD  ...
# 998                              삼성전자 삼성 DM500T7Z-AD2S  ...      삼성
# 999  명컴퓨터 인텔 G4900 4GB H310M SSD 128GB장착 컴퓨터 조립PC /...  ...
#
# [1000 rows x 10 columns]
